# %% [markdown]
# # Question2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## (a)

# %%
d = {'X1': [3, 2, 4, 1, 2, 4, 4], 'X2': [4, 2, 4, 4, 1, 3, 1], 'Y':["Red", "Red", "Red", "Red", "Blue", "Blue", "Blue"]}
toy_data = pd.DataFrame(data=d)
print(toy_data)
# Out:
#    X1  X2     Y
# 0   3   4   Red
# 1   2   2   Red
# 2   4   4   Red
# 3   1   4   Red
# 4   2   1  Blue
# 5   4   3  Blue
# 6   4   1  Blue

# %%
X1 = np.array([3, 2, 4, 1, 2, 4, 4])
X2 = np.array([4, 2, 4, 4, 1, 3, 1])
X = [[a,b] for a, b in zip(X1, X2)]
Y = ["Red", "Red", "Red", "Red", "Blue", "Blue", "Blue"]

# %%
colors = np.array(["red", "red", "red", "red", "blue", "blue", "blue"])
plt.scatter(toy_data['X1'], toy_data['X2'], c = colors)

# %% [markdown]
# ## (b)
# Equation: $ \beta_{0} + \beta_{1}{X_{1}} + \beta_{2}{X_{2}} = 0$

# %%
clf = svm.SVC(kernel = 'linear', C = 10)
clf.fit(np.array(X), np.array(Y))
# Out:
# SVC(C=10, kernel='linear')

# %%
clf.coef_
# Out:
# array([[-1.99941406,  1.99941406]])

# %%
clf.intercept_
# Out:
# array([0.99970703])

# %%
colors = np.array(["red", "red", "red", "red", "blue", "blue", "blue"])
plt.scatter(toy_data['X1'], toy_data['X2'], c = colors)
plt.plot(X1, X1 - 0.5, '-y')

# %% [markdown]
# ## (c)
# Optimal separating hyperplane equation: $ 0.5 - X_{1} + X_{2} = 0$, which $ \beta_{0} = 0.5, \beta_{1} = -1, \beta_{2} = 1 $, dot (1,4),(2,2),(3,4),(4,4) as a group which  $ 0.5 - X_{1} + X_{2} > 0$, and other dots will be as the other group $ 0.5 - X_{1} + X_{2} < 0$
# ## (d)、(e)
# Support vectors are circled in black.

# %%
from sklearn.inspection import DecisionBoundaryDisplay
colors = np.array(["red", "red", "red", "red", "blue", "blue", "blue"])
plt.scatter([2,2,4,4], [1,2,3,4], s=80, edgecolors='black')
plt.scatter(toy_data['X1'], toy_data['X2'], c = colors)
plt.plot(X1, X1 - 0.5, '-y')
plt.plot(X1, X1 - 1 ,'gold', ls = 'dashed')
plt.plot(X1, X1, 'gold', ls = 'dashed')
plt.show()

# %% [markdown]
# ## (f)
# 如果hyperplane與support vectors之間距離仍然相同，則第七個觀察值是可以在X2 = X1 - 1式子以下任意移動的

# %% [markdown]
# ## (g)

# %%
clf_1 = svm.SVC(kernel = 'linear', C = 1)
clf_1.fit(np.array(X), np.array(Y))
# Out:
# SVC(C=1, kernel='linear')

# %%
print(clf_1.coef_,clf_1.intercept_)
# Out:
# [[-0.61538462  1.07692308]] [-0.84615385]

# %%
colors = np.array(["red", "red", "red", "red", "blue", "blue", "blue"])
plt.scatter(toy_data['X1'], toy_data['X2'], c = colors)
plt.plot(X1, 1.25*X1 - 0.25, '-y')

# %% [markdown]
# ## (h)

# %%
from sklearn.inspection import DecisionBoundaryDisplay
colors = np.array(["red", "red", "red", "red", "blue", "blue", "blue"])
plt.scatter([2,2,4,4], [1,2,3,4], s=80, edgecolors='black')
plt.scatter(toy_data['X1'], toy_data['X2'], c = colors)
plt.plot(X1, X1 - 0.5, '-y')
plt.plot(X1, X1 - 1 ,'gold', ls = 'dashed')
plt.plot(X1, X1, 'gold', ls = 'dashed')
plt.plot(1.5, 3.5, 'bo')  
plt.show()
